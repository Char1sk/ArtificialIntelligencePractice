# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('./exp01.txt') as f:
    lines = f.readlines()
    trainmiou01 = []
    testmiou01 = []
    for l in lines:
        if 'Train' in l:
            i = float(l[31:37])
            trainmiou01.append(i)
        if 'Test' in l:
            i = float(l[31:37])
            testmiou01.append(i)
trainmiou01 = trainmiou01[0:20]
testmiou01 = testmiou01[0:20]
plt.plot(range(1, 21), trainmiou01)
plt.plot(range(1, 21), testmiou01)

# %%
with open('./exp02.txt') as f:
    lines = f.readlines()
    trainmiou02 = []
    testmiou02 = []
    for l in lines:
        if 'Train' in l:
            i = float(l[31:37])
            trainmiou02.append(i)
        if 'Test' in l:
            i = float(l[31:37])
            testmiou02.append(i)
trainmiou02 = trainmiou02[0:20]
testmiou02 = testmiou02[0:20]
plt.plot(range(1, 21), trainmiou02)
plt.plot(range(1, 21), testmiou02)

# %%
with open('./results/exp1.txt') as f:
    lines = f.readlines()
    trainacc1 = []
    testacc1 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc1.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc1.append(i)

with open('./results/exp2.txt') as f:
    lines = f.readlines()
    trainacc2 = []
    testacc2 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc2.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc2.append(i)

with open('./results/exp4.txt') as f:
    lines = f.readlines()
    trainacc4 = []
    testacc4 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc4.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc4.append(i)

with open('./results/exp7.txt') as f:
    lines = f.readlines()
    trainacc7 = []
    testacc7 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc7.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc7.append(i)

with open('./results/exp44.txt') as f:
    lines = f.readlines()
    trainacc44 = []
    testacc44 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc44.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc44.append(i)

with open('./results/exp77.txt') as f:
    lines = f.readlines()
    trainacc77 = []
    testacc77 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc77.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc77.append(i)
# 1247

# %%
plt.plot(testacc1, '-')
plt.plot(testacc2, '-')
plt.plot(testacc4, '-')
plt.plot(testacc7, '-')
plt.legend(['exp1', 'exp2', 'exp3', 'exp4'])
plt.show()

# %%
plt.plot(testacc1, '-')
plt.plot(testacc2, '-')
plt.legend(['exp1', 'exp2'])
plt.show()

# %%
plt.plot(testacc2+testacc2[-10:], '-')
plt.plot(testacc4, '-')
plt.legend(['exp2', 'exp3'])
plt.show()

# %%
with open('./results/exp3.txt') as f:
    lines = f.readlines()
    trainacc3 = []
    testacc3 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc3.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc3.append(i)

with open('./results/exp5.txt') as f:
    lines = f.readlines()
    trainacc5 = []
    testacc5 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc5.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc5.append(i)

with open('./results/exp6.txt') as f:
    lines = f.readlines()
    trainacc6 = []
    testacc6 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc6.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc6.append(i)

with open('./results/exp8.txt') as f:
    lines = f.readlines()
    trainacc8 = []
    testacc8 = []
    for l in lines:
        if 'Train' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            trainacc8.append(i)
        if 'Test' in l and 'Acc' in l:
            a = l.find('Acc ')
            b = l.find('%')
            i = float(l[a+4:b])*100
            testacc8.append(i)

# %%
plt.plot(testacc3, '-')
plt.plot(testacc5, '-')
plt.plot(testacc6, '-')
plt.plot(testacc8, '-')
plt.legend(['exp5', 'exp6', 'exp7', 'exp8'])
plt.show()
print(testacc3[-1])
print(testacc5[-1])
print(testacc6[-1])
print(testacc8[-1])
# Out:
# 78.9
# 75.87
# 77.63
# 86.22999999999999

# %%
plt.plot(testacc5, '-')
plt.plot(testacc6, '-')
plt.legend(['exp6', 'exp7'])
plt.show()

# %%
plt.plot(testacc6, '-')
plt.plot(testacc8, '-')
plt.legend(['exp7', 'exp8'])
plt.show()

# %%
plt.plot(testacc77, '-')
plt.plot(testacc8, '-')
plt.legend(['exp4*', 'exp8'])
plt.show()

# %%
# plt.plot(trainacc44, '-bo')
plt.plot(testacc44, '-')
# plt.plot(trainacc7, '-ro')
plt.plot(testacc77, '-')
plt.legend(['exp3', 'exp4*'])
plt.show()

# %%
print(len(trainacc1))
print(len(trainacc2))
print(len(trainacc3))
print(len(trainacc4))
print(len(trainacc5))
print(len(trainacc6))
print(len(trainacc7))
print(len(trainacc8))
# Out:
# 18
# 31
# 8
# 43
# 79
# 65
# 64
# 64
